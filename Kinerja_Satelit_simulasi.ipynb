# %% [markdown]
# <a href="https://colab.research.google.com/github/gandalfmuda/Data-Scientis-mastery/blob/main/Kinerja_Satelit_simulasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

print("🛰️ Simulasi Kinerja Satelit 🛰️")
print("👨🏻‍🚀 bot pilot: Ari")

# data orbit pesawat satelit

data_orbit = np.array([[0, 0], [1, 1], [2, 4], [3, 9], [4, 16]])

# pisahkan data ke x dan y

x = data_orbit[:, 0]
y = data_orbit[:, 1]

# hitung kecepatan satelit

velocity = np.diff(y) / np.diff(x)

# tampilkan grafik orbit dan kecepatan satelit

plt.plot(x, y, label='Orbit')
plt.plot(x[:-1], velocity, label='Kecepatan')
plt.xlabel('Waktu')
plt.ylabel('Parameter')
plt.legend()
plt.show()
# Out:
# 🛰️ Simulasi Kinerja Satelit 🛰️
# 👨🏻‍🚀 bot pilot: Ari
